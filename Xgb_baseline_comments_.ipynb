# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from nltk.corpus import stopwords
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import xgboost as xgb
import gc
from sklearn.feature_extraction.text import TfidfVectorizer
import scipy

# %%
import scipy

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

train = train.fillna("unknown")
test = test.fillna("unknown")

# %%
train_mes, valid_mes, train_l, valid_l = train_test_split(train['comment_text'],train[['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']], test_size=0.2, random_state=2)

# %%
train_mes.head(2)
# Out:
# 91312    "\n\nTemplate:Shortcut\n\nOut of curiosity, wh...
# 86103    I always got the impression he was a real cunt...
# Name: comment_text, dtype: object

# %%
valid_mes.head(2)
# Out:
# 57791    In reference to the formula 1-(-1) = 2 you pos...
# 16982    Sir William Lawrence, 1st Baronet \n\nObviousl...
# Name: comment_text, dtype: object

# %%
train_l.head(2)
# Out:
#        toxic  severe_toxic  obscene  threat  insult  identity_hate
# 91312      0             0        0       0       0              0
# 86103      0             0        1       0       1              0

# %%
valid_l.head(2)
# Out:
#        toxic  severe_toxic  obscene  threat  insult  identity_hate
# 57791      0             0        0       0       0              0
# 16982      0             0        0       0       0              0

# %%
import re, string
re_tok = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')
def tokenize(s): return re_tok.sub(r' \1 ', s).split()

# %%
transform_com = TfidfVectorizer(ngram_range=(1,3),tokenizer=tokenize,analyzer='char',
               min_df=3, max_df=0.9, strip_accents='unicode', use_idf=1,
               smooth_idf=1, sublinear_tf=1).fit(train['comment_text'])

# %%
comments_train = transform_com.transform(train_mes)
comments_valid = transform_com.transform(valid_mes)

# %%
comments_test = transform_com.transform(test['comment_text'])

# %%
gc.collect()
# Out:
# 73

# %%
train_mes = pd.DataFrame(train_mes)
valid_mes = pd.DataFrame(valid_mes)

# %%
data = [train_mes, valid_mes, test]

# %%
for element in data:
    element['total_length'] = element['comment_text'].apply(len)
    element['capitals'] = element['comment_text'].apply(lambda comment: sum(1 for c in comment if c.isupper()))
    element['caps_vs_length'] = element.apply(lambda row: float(row['capitals'])/float(row['total_length']),
                                axis=1)
    element['num_exclamation_marks'] = element['comment_text'].apply(lambda comment: comment.count('!'))
    element['num_question_marks'] = element['comment_text'].apply(lambda comment: comment.count('?'))
    element['num_punctuation'] = element['comment_text'].apply(lambda comment: sum(comment.count(w) for w in '.,;:'))
    element['num_symbols'] = element['comment_text'].apply(lambda comment: sum(comment.count(w) for w in '*&$%'))
    element['num_words'] = element['comment_text'].apply(lambda comment: len(comment.split()))
    element['num_unique_words'] = element['comment_text'].apply(lambda comment: len(set(w for w in comment.split())))
    element['words_vs_unique'] = element['num_unique_words'] / element['num_words']
    element['num_smilies'] = element['comment_text'].apply(lambda comment: sum(comment.count(w) for w in (':-)', ':)', ';-)', ';)')))

# %%
col = ['total_length', 'capitals', 'caps_vs_length',
       'num_exclamation_marks', 'num_question_marks', 'num_punctuation',
       'num_symbols', 'num_words', 'num_unique_words', 'words_vs_unique',
       'num_smilies']

# %%
train_mes = scipy.sparse.csr_matrix(train_mes[col].values)
valid_mes = scipy.sparse.csr_matrix(valid_mes[col].values)
test = scipy.sparse.csr_matrix(test[col].values)

# %%
import xgboost as xgb

# %%
def runXGB(train_X, train_y, test_X, test_y=None, feature_names=None, seed_val=2017, num_rounds=500):
    param = {}
    param['objective'] = 'binary:logistic'
    param['eta'] = 0.1
    param['max_depth'] = 6
    param['silent'] = 1
    param['eval_metric'] = 'auc'
    param['min_child_weight'] = 1
    param['subsample'] = 0.7
    param['colsample_bytree'] = 0.7
    param['seed'] = seed_val
    num_rounds = num_rounds

    plst = list(param.items())
    xgtrain = xgb.DMatrix(train_X, label=train_y)

    if test_y is not None:
        xgtest = xgb.DMatrix(test_X, label=test_y)
        watchlist = [ (xgtrain,'train'), (xgtest, 'test') ]
        model = xgb.train(plst, xgtrain, num_rounds, watchlist, early_stopping_rounds=20)
    else:
        xgtest = xgb.DMatrix(test_X)
        model = xgb.train(plst, xgtrain, num_rounds)

    return model

# %%
col = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

# %%
preds = np.zeros((test.shape[0], len(col)))

# %%
for i, j in enumerate(col):
    print('fit '+j)
    model = runXGB(comments_train, train_l[j], comments_valid,valid_l[j])
    preds[:,i] = model.predict(xgb.DMatrix(comments_test), ntree_limit = model.best_ntree_limit)
# Out:
# fit toxic
# [0]	train-auc:0.774743	test-auc:0.771865
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.818378	test-auc:0.811372
# [2]	train-auc:0.847807	test-auc:0.840707
# [3]	train-auc:0.853439	test-auc:0.845658
# [4]	train-auc:0.855188	test-auc:0.847146
# [5]	train-auc:0.85909	test-auc:0.850699
# [6]	train-auc:0.86262	test-auc:0.854869
# [7]	train-auc:0.882407	test-auc:0.874645
# [8]	train-auc:0.889507	test-auc:0.880181
# [9]	train-auc:0.892054	test-auc:0.88317
# [10]	train-auc:0.894995	test-auc:0.886343
# [11]	train-auc:0.897552	test-auc:0.889041
# [12]	train-auc:0.899423	test-auc:0.89044
# [13]	train-auc:0.90369	test-auc:0.894621
# [14]	train-auc:0.905154	test-auc:0.896713
# [15]	train-auc:0.907516	test-auc:0.898973
# [16]	train-auc:0.913106	test-auc:0.904034
# [17]	train-auc:0.915634	test-auc:0.906192
# [18]	train-auc:0.91729	test-auc:0.907331
# [19]	train-auc:0.919532	test-auc:0.909415
# [20]	train-auc:0.920782	test-auc:0.91042
# [21]	train-auc:0.923133	test-auc:0.911981
# [22]	train-auc:0.924979	test-auc:0.913997
# [23]	train-auc:0.927154	test-auc:0.915174
# [24]	train-auc:0.928728	test-auc:0.91609
# [25]	train-auc:0.929906	test-auc:0.916827
# [26]	train-auc:0.932089	test-auc:0.917986
# [27]	train-auc:0.933676	test-auc:0.919373
# [28]	train-auc:0.936168	test-auc:0.921519
# [29]	train-auc:0.938149	test-auc:0.922884
# [30]	train-auc:0.939328	test-auc:0.923499
# [31]	train-auc:0.941424	test-auc:0.925054
# [32]	train-auc:0.942944	test-auc:0.926037
# [33]	train-auc:0.943835	test-auc:0.92678
# [34]	train-auc:0.945269	test-auc:0.928224
# [35]	train-auc:0.946065	test-auc:0.929222
# [36]	train-auc:0.9478	test-auc:0.930497
# [37]	train-auc:0.949128	test-auc:0.93142
# [38]	train-auc:0.95036	test-auc:0.932242
# [39]	train-auc:0.951434	test-auc:0.932929
# [40]	train-auc:0.952112	test-auc:0.933538
# [41]	train-auc:0.952945	test-auc:0.934331
# [42]	train-auc:0.953793	test-auc:0.935429
# [43]	train-auc:0.95478	test-auc:0.936086
# [44]	train-auc:0.955441	test-auc:0.936975
# [45]	train-auc:0.956192	test-auc:0.937897
# [46]	train-auc:0.957038	test-auc:0.938316
# [47]	train-auc:0.957475	test-auc:0.938758
# [48]	train-auc:0.957916	test-auc:0.938926
# [49]	train-auc:0.958653	test-auc:0.939206
# [50]	train-auc:0.959765	test-auc:0.940176
# [51]	train-auc:0.960492	test-auc:0.940646
# [52]	train-auc:0.961301	test-auc:0.941172
# [53]	train-auc:0.961849	test-auc:0.941595
# [54]	train-auc:0.962062	test-auc:0.941693
# [55]	train-auc:0.962603	test-auc:0.942182
# [56]	train-auc:0.963423	test-auc:0.942864
# [57]	train-auc:0.963731	test-auc:0.943101
# [58]	train-auc:0.964199	test-auc:0.94357
# [59]	train-auc:0.96488	test-auc:0.943937
# [60]	train-auc:0.965514	test-auc:0.944334
# [61]	train-auc:0.96579	test-auc:0.944711
# [62]	train-auc:0.966056	test-auc:0.945174
# [63]	train-auc:0.96668	test-auc:0.945479
# [64]	train-auc:0.967151	test-auc:0.945859
# [65]	train-auc:0.967575	test-auc:0.946243
# [66]	train-auc:0.968252	test-auc:0.946629
# [67]	train-auc:0.968596	test-auc:0.94698
# [68]	train-auc:0.969205	test-auc:0.94765
# [69]	train-auc:0.969651	test-auc:0.947956
# [70]	train-auc:0.970065	test-auc:0.948228
# [71]	train-auc:0.970488	test-auc:0.948391
# [72]	train-auc:0.970762	test-auc:0.948746
# [73]	train-auc:0.971029	test-auc:0.949035
# [74]	train-auc:0.971289	test-auc:0.94935
# [75]	train-auc:0.971698	test-auc:0.949935
# [76]	train-auc:0.972104	test-auc:0.950324
# [77]	train-auc:0.972557	test-auc:0.950673
# [78]	train-auc:0.972942	test-auc:0.951001
# [79]	train-auc:0.973122	test-auc:0.95129
# [80]	train-auc:0.973335	test-auc:0.951644
# [81]	train-auc:0.973588	test-auc:0.951791
# [82]	train-auc:0.973983	test-auc:0.952097
# [83]	train-auc:0.9742	test-auc:0.95231
# [84]	train-auc:0.974453	test-auc:0.952689
# [85]	train-auc:0.974702	test-auc:0.952932
# [86]	train-auc:0.974976	test-auc:0.953125
# [87]	train-auc:0.975223	test-auc:0.953328
# [88]	train-auc:0.975564	test-auc:0.953552
# [89]	train-auc:0.975824	test-auc:0.953766
# [90]	train-auc:0.976099	test-auc:0.954051
# [91]	train-auc:0.976346	test-auc:0.954241
# [92]	train-auc:0.976522	test-auc:0.954386
# [93]	train-auc:0.976746	test-auc:0.954451
# [94]	train-auc:0.977063	test-auc:0.95464
# [95]	train-auc:0.977299	test-auc:0.954889
# [96]	train-auc:0.97744	test-auc:0.955008
# [97]	train-auc:0.977713	test-auc:0.955108
# [98]	train-auc:0.977969	test-auc:0.955341
# [99]	train-auc:0.97809	test-auc:0.955519
# [100]	train-auc:0.978297	test-auc:0.955615
# [101]	train-auc:0.97859	test-auc:0.955843
# [102]	train-auc:0.97881	test-auc:0.955918
# [103]	train-auc:0.979039	test-auc:0.956089
# [104]	train-auc:0.979242	test-auc:0.956255
# [105]	train-auc:0.979445	test-auc:0.956463
# [106]	train-auc:0.979603	test-auc:0.95671
# [107]	train-auc:0.979835	test-auc:0.956818
# [108]	train-auc:0.980101	test-auc:0.957038
# [109]	train-auc:0.980284	test-auc:0.957052
# [110]	train-auc:0.980568	test-auc:0.95712
# [111]	train-auc:0.980708	test-auc:0.957312
# [112]	train-auc:0.980855	test-auc:0.957513
# [113]	train-auc:0.981108	test-auc:0.957635
# [114]	train-auc:0.981255	test-auc:0.957741
# [115]	train-auc:0.981532	test-auc:0.957922
# [116]	train-auc:0.981733	test-auc:0.958173
# [117]	train-auc:0.981885	test-auc:0.958268
# [118]	train-auc:0.982051	test-auc:0.958267
# [119]	train-auc:0.982094	test-auc:0.958339
# [120]	train-auc:0.982274	test-auc:0.958434
# [121]	train-auc:0.982399	test-auc:0.958472
# [122]	train-auc:0.98249	test-auc:0.958673
# [123]	train-auc:0.982598	test-auc:0.958682
# [124]	train-auc:0.98275	test-auc:0.958745
# [125]	train-auc:0.983014	test-auc:0.958934
# [126]	train-auc:0.983121	test-auc:0.959018
# [127]	train-auc:0.983356	test-auc:0.95912
# [128]	train-auc:0.983423	test-auc:0.959175
# [129]	train-auc:0.983614	test-auc:0.959243
# [130]	train-auc:0.98381	test-auc:0.959266
# [131]	train-auc:0.984032	test-auc:0.959239
# [132]	train-auc:0.984139	test-auc:0.959385
# [133]	train-auc:0.984263	test-auc:0.959591
# [134]	train-auc:0.984358	test-auc:0.95965
# [135]	train-auc:0.98452	test-auc:0.959799
# [136]	train-auc:0.984626	test-auc:0.959868
# [137]	train-auc:0.984723	test-auc:0.959987
# [138]	train-auc:0.984898	test-auc:0.960025
# [139]	train-auc:0.984996	test-auc:0.960093
# [140]	train-auc:0.985155	test-auc:0.960231
# [141]	train-auc:0.985303	test-auc:0.960267
# [142]	train-auc:0.985413	test-auc:0.960446
# [143]	train-auc:0.985611	test-auc:0.960538
# [144]	train-auc:0.985762	test-auc:0.960642
# [145]	train-auc:0.98593	test-auc:0.960707
# [146]	train-auc:0.986054	test-auc:0.960696
# [147]	train-auc:0.986225	test-auc:0.96081
# [148]	train-auc:0.986379	test-auc:0.960911
# [149]	train-auc:0.986466	test-auc:0.961053
# [150]	train-auc:0.986615	test-auc:0.961261
# [151]	train-auc:0.986704	test-auc:0.961295
# [152]	train-auc:0.98676	test-auc:0.961412
# [153]	train-auc:0.986888	test-auc:0.961593
# [154]	train-auc:0.987002	test-auc:0.961668
# [155]	train-auc:0.987074	test-auc:0.961642
# [156]	train-auc:0.987141	test-auc:0.961641
# [157]	train-auc:0.987214	test-auc:0.961762
# [158]	train-auc:0.987315	test-auc:0.961776
# [159]	train-auc:0.987401	test-auc:0.96185
# [160]	train-auc:0.987469	test-auc:0.961898
# [161]	train-auc:0.987535	test-auc:0.961971
# [162]	train-auc:0.987658	test-auc:0.962061
# [163]	train-auc:0.987828	test-auc:0.962278
# [164]	train-auc:0.987889	test-auc:0.962265
# [165]	train-auc:0.988031	test-auc:0.962298
# [166]	train-auc:0.988085	test-auc:0.962281
# [167]	train-auc:0.988202	test-auc:0.962309
# [168]	train-auc:0.988298	test-auc:0.962329
# [169]	train-auc:0.988379	test-auc:0.962365
# [170]	train-auc:0.988436	test-auc:0.962425
# [171]	train-auc:0.988543	test-auc:0.962517
# [172]	train-auc:0.988592	test-auc:0.962599
# [173]	train-auc:0.988706	test-auc:0.962731
# [174]	train-auc:0.988777	test-auc:0.962777
# [175]	train-auc:0.988872	test-auc:0.962832
# [176]	train-auc:0.98897	test-auc:0.962914
# [177]	train-auc:0.989061	test-auc:0.962968
# [178]	train-auc:0.989148	test-auc:0.96308
# [179]	train-auc:0.989235	test-auc:0.963066
# [180]	train-auc:0.989286	test-auc:0.963118
# [181]	train-auc:0.989343	test-auc:0.963233
# [182]	train-auc:0.989411	test-auc:0.963262
# [183]	train-auc:0.98945	test-auc:0.963311
# [184]	train-auc:0.989515	test-auc:0.96334
# [185]	train-auc:0.989572	test-auc:0.963446
# [186]	train-auc:0.989617	test-auc:0.963485
# [187]	train-auc:0.989735	test-auc:0.963555
# [188]	train-auc:0.989808	test-auc:0.963585
# [189]	train-auc:0.989925	test-auc:0.963591
# [190]	train-auc:0.990002	test-auc:0.963616
# [191]	train-auc:0.990057	test-auc:0.963692
# [192]	train-auc:0.990143	test-auc:0.963745
# [193]	train-auc:0.990174	test-auc:0.963755
# [194]	train-auc:0.990202	test-auc:0.963821
# [195]	train-auc:0.990287	test-auc:0.963892
# [196]	train-auc:0.990364	test-auc:0.963848
# [197]	train-auc:0.990425	test-auc:0.963817
# [198]	train-auc:0.99051	test-auc:0.963879
# [199]	train-auc:0.990579	test-auc:0.963982
# [200]	train-auc:0.990646	test-auc:0.963986
# [201]	train-auc:0.990706	test-auc:0.963953
# [202]	train-auc:0.990778	test-auc:0.9639
# [203]	train-auc:0.990838	test-auc:0.963935
# [204]	train-auc:0.990947	test-auc:0.963915
# [205]	train-auc:0.991032	test-auc:0.96394
# [206]	train-auc:0.991098	test-auc:0.963984
# [207]	train-auc:0.991134	test-auc:0.963983
# [208]	train-auc:0.991194	test-auc:0.963986
# [209]	train-auc:0.991237	test-auc:0.963924
# [210]	train-auc:0.991327	test-auc:0.963942
# [211]	train-auc:0.991368	test-auc:0.963968
# [212]	train-auc:0.991411	test-auc:0.963986
# [213]	train-auc:0.991471	test-auc:0.964113
# [214]	train-auc:0.991541	test-auc:0.964201
# [215]	train-auc:0.991625	test-auc:0.964251
# [216]	train-auc:0.99169	test-auc:0.964341
# [217]	train-auc:0.99176	test-auc:0.964349
# [218]	train-auc:0.991823	test-auc:0.964397
# [219]	train-auc:0.99189	test-auc:0.96453
# [220]	train-auc:0.991953	test-auc:0.964554
# [221]	train-auc:0.992004	test-auc:0.964577
# [222]	train-auc:0.992069	test-auc:0.96462
# [223]	train-auc:0.992106	test-auc:0.964612
# [224]	train-auc:0.99214	test-auc:0.964648
# [225]	train-auc:0.99217	test-auc:0.964666
# [226]	train-auc:0.992262	test-auc:0.964749
# [227]	train-auc:0.992338	test-auc:0.964775
# [228]	train-auc:0.992418	test-auc:0.964801
# [229]	train-auc:0.992459	test-auc:0.964776
# [230]	train-auc:0.992491	test-auc:0.96483
# [231]	train-auc:0.992529	test-auc:0.9648
# [232]	train-auc:0.992565	test-auc:0.964813
# [233]	train-auc:0.992596	test-auc:0.964903
# [234]	train-auc:0.992623	test-auc:0.964907
# [235]	train-auc:0.992674	test-auc:0.964922
# [236]	train-auc:0.992709	test-auc:0.964942
# [237]	train-auc:0.992762	test-auc:0.964956
# [238]	train-auc:0.992815	test-auc:0.96497
# [239]	train-auc:0.992858	test-auc:0.964967
# [240]	train-auc:0.992872	test-auc:0.965007
# [241]	train-auc:0.992914	test-auc:0.965045
# [242]	train-auc:0.992962	test-auc:0.965054
# [243]	train-auc:0.992991	test-auc:0.965093
# [244]	train-auc:0.993041	test-auc:0.965102
# [245]	train-auc:0.993097	test-auc:0.965146
# [246]	train-auc:0.993172	test-auc:0.965113
# [247]	train-auc:0.993257	test-auc:0.965144
# [248]	train-auc:0.993317	test-auc:0.965213
# [249]	train-auc:0.993332	test-auc:0.965205
# [250]	train-auc:0.993406	test-auc:0.965254
# [251]	train-auc:0.993441	test-auc:0.965327
# [252]	train-auc:0.993475	test-auc:0.965373
# [253]	train-auc:0.993543	test-auc:0.965438
# [254]	train-auc:0.993586	test-auc:0.965438
# [255]	train-auc:0.993642	test-auc:0.965501
# [256]	train-auc:0.993676	test-auc:0.965503
# [257]	train-auc:0.993715	test-auc:0.965519
# [258]	train-auc:0.99374	test-auc:0.96552
# [259]	train-auc:0.993774	test-auc:0.965534
# [260]	train-auc:0.993827	test-auc:0.965598
# [261]	train-auc:0.993861	test-auc:0.965601
# [262]	train-auc:0.99392	test-auc:0.965682
# [263]	train-auc:0.993944	test-auc:0.965649
# [264]	train-auc:0.993976	test-auc:0.965677
# [265]	train-auc:0.994034	test-auc:0.965678
# [266]	train-auc:0.994069	test-auc:0.965683
# [267]	train-auc:0.994096	test-auc:0.965684
# [268]	train-auc:0.994169	test-auc:0.965745
# [269]	train-auc:0.994199	test-auc:0.965761
# [270]	train-auc:0.994243	test-auc:0.965757
# [271]	train-auc:0.994354	test-auc:0.965783
# [272]	train-auc:0.994379	test-auc:0.965774
# [273]	train-auc:0.99441	test-auc:0.965784
# [274]	train-auc:0.994442	test-auc:0.965832
# [275]	train-auc:0.994484	test-auc:0.965905
# [276]	train-auc:0.994524	test-auc:0.965886
# [277]	train-auc:0.994554	test-auc:0.965875
# [278]	train-auc:0.994603	test-auc:0.965918
# [279]	train-auc:0.99463	test-auc:0.965968
# [280]	train-auc:0.99466	test-auc:0.966009
# [281]	train-auc:0.994694	test-auc:0.966008
# [282]	train-auc:0.994712	test-auc:0.966028
# [283]	train-auc:0.99474	test-auc:0.966038
# [284]	train-auc:0.994758	test-auc:0.966062
# [285]	train-auc:0.994795	test-auc:0.966102
# [286]	train-auc:0.994874	test-auc:0.966101
# [287]	train-auc:0.994897	test-auc:0.966103
# [288]	train-auc:0.994963	test-auc:0.966151
# [289]	train-auc:0.995012	test-auc:0.96621
# [290]	train-auc:0.995064	test-auc:0.966237
# [291]	train-auc:0.995088	test-auc:0.966202
# [292]	train-auc:0.995106	test-auc:0.966211
# [293]	train-auc:0.995168	test-auc:0.966264
# [294]	train-auc:0.995218	test-auc:0.966263
# [295]	train-auc:0.995242	test-auc:0.966291
# [296]	train-auc:0.995275	test-auc:0.96629
# [297]	train-auc:0.995301	test-auc:0.966287
# [298]	train-auc:0.995324	test-auc:0.966294
# [299]	train-auc:0.995363	test-auc:0.966397
# [300]	train-auc:0.995374	test-auc:0.966428
# [301]	train-auc:0.995397	test-auc:0.966447
# [302]	train-auc:0.995429	test-auc:0.96645
# [303]	train-auc:0.99547	test-auc:0.966479
# [304]	train-auc:0.995492	test-auc:0.966528
# [305]	train-auc:0.995528	test-auc:0.96656
# [306]	train-auc:0.995548	test-auc:0.966576
# [307]	train-auc:0.995576	test-auc:0.966585
# [308]	train-auc:0.995609	test-auc:0.966649
# [309]	train-auc:0.995635	test-auc:0.966668
# [310]	train-auc:0.995657	test-auc:0.966735
# [311]	train-auc:0.995683	test-auc:0.96678
# [312]	train-auc:0.99571	test-auc:0.966817
# [313]	train-auc:0.995753	test-auc:0.966819
# [314]	train-auc:0.995811	test-auc:0.966896
# [315]	train-auc:0.995825	test-auc:0.966954
# [316]	train-auc:0.995875	test-auc:0.966987
# [317]	train-auc:0.995892	test-auc:0.967013
# [318]	train-auc:0.995916	test-auc:0.967066
# [319]	train-auc:0.995945	test-auc:0.967078
# [320]	train-auc:0.995971	test-auc:0.967094
# [321]	train-auc:0.995993	test-auc:0.967119
# [322]	train-auc:0.996005	test-auc:0.96713
# [323]	train-auc:0.996043	test-auc:0.967125
# [324]	train-auc:0.996056	test-auc:0.967147
# [325]	train-auc:0.996094	test-auc:0.967194
# [326]	train-auc:0.996108	test-auc:0.967263
# [327]	train-auc:0.996125	test-auc:0.967247
# [328]	train-auc:0.996145	test-auc:0.967243
# [329]	train-auc:0.996173	test-auc:0.967275
# [330]	train-auc:0.996209	test-auc:0.967294
# [331]	train-auc:0.996225	test-auc:0.967334
# [332]	train-auc:0.996248	test-auc:0.967411
# [333]	train-auc:0.996284	test-auc:0.967449
# [334]	train-auc:0.996309	test-auc:0.967471
# [335]	train-auc:0.996337	test-auc:0.967449
# [336]	train-auc:0.996355	test-auc:0.967475
# [337]	train-auc:0.996381	test-auc:0.967479
# [338]	train-auc:0.996398	test-auc:0.967471
# [339]	train-auc:0.996413	test-auc:0.967515
# [340]	train-auc:0.996444	test-auc:0.967548
# [341]	train-auc:0.996485	test-auc:0.967548
# [342]	train-auc:0.996526	test-auc:0.967568
# [343]	train-auc:0.996548	test-auc:0.967577
# [344]	train-auc:0.996574	test-auc:0.967567
# [345]	train-auc:0.99659	test-auc:0.967529
# [346]	train-auc:0.996603	test-auc:0.96754
# [347]	train-auc:0.99663	test-auc:0.967516
# [348]	train-auc:0.996652	test-auc:0.967528
# [349]	train-auc:0.996684	test-auc:0.96757
# [350]	train-auc:0.9967	test-auc:0.967546
# [351]	train-auc:0.996726	test-auc:0.967558
# [352]	train-auc:0.996735	test-auc:0.967563
# [353]	train-auc:0.996767	test-auc:0.967557
# [354]	train-auc:0.9968	test-auc:0.967599
# [355]	train-auc:0.996827	test-auc:0.967611
# [356]	train-auc:0.996843	test-auc:0.967637
# [357]	train-auc:0.996864	test-auc:0.967682
# [358]	train-auc:0.99688	test-auc:0.967705
# [359]	train-auc:0.996909	test-auc:0.967748
# [360]	train-auc:0.996921	test-auc:0.967759
# [361]	train-auc:0.996945	test-auc:0.967763
# [362]	train-auc:0.99696	test-auc:0.96783
# [363]	train-auc:0.996977	test-auc:0.96785
# [364]	train-auc:0.997011	test-auc:0.967883
# [365]	train-auc:0.997025	test-auc:0.967905
# [366]	train-auc:0.997033	test-auc:0.967907
# [367]	train-auc:0.997054	test-auc:0.967919
# [368]	train-auc:0.997073	test-auc:0.967924
# [369]	train-auc:0.997081	test-auc:0.967912
# [370]	train-auc:0.997101	test-auc:0.967891
# [371]	train-auc:0.997116	test-auc:0.967867
# [372]	train-auc:0.997137	test-auc:0.967846
# [373]	train-auc:0.997153	test-auc:0.96786
# [374]	train-auc:0.997161	test-auc:0.967922
# [375]	train-auc:0.99721	test-auc:0.967996
# [376]	train-auc:0.997233	test-auc:0.967979
# [377]	train-auc:0.997243	test-auc:0.967999
# [378]	train-auc:0.997255	test-auc:0.968045
# [379]	train-auc:0.997272	test-auc:0.968062
# [380]	train-auc:0.99729	test-auc:0.968096
# [381]	train-auc:0.997302	test-auc:0.968138
# [382]	train-auc:0.997322	test-auc:0.968252
# [383]	train-auc:0.997336	test-auc:0.968248
# [384]	train-auc:0.997342	test-auc:0.968284
# [385]	train-auc:0.997372	test-auc:0.968312
# [386]	train-auc:0.997383	test-auc:0.968294
# [387]	train-auc:0.997391	test-auc:0.968277
# [388]	train-auc:0.997415	test-auc:0.968316
# [389]	train-auc:0.997421	test-auc:0.968316
# [390]	train-auc:0.997454	test-auc:0.968301
# [391]	train-auc:0.997479	test-auc:0.968298
# [392]	train-auc:0.997506	test-auc:0.968296
# [393]	train-auc:0.997533	test-auc:0.968275
# [394]	train-auc:0.997546	test-auc:0.968309
# [395]	train-auc:0.997571	test-auc:0.968359
# [396]	train-auc:0.997597	test-auc:0.968363
# [397]	train-auc:0.997603	test-auc:0.968364
# [398]	train-auc:0.997621	test-auc:0.968358
# [399]	train-auc:0.997636	test-auc:0.968349
# [400]	train-auc:0.997647	test-auc:0.968307
# [401]	train-auc:0.997658	test-auc:0.96834
# [402]	train-auc:0.997666	test-auc:0.968368
# [403]	train-auc:0.997678	test-auc:0.968351
# [404]	train-auc:0.997702	test-auc:0.968394
# [405]	train-auc:0.997712	test-auc:0.96841
# [406]	train-auc:0.997725	test-auc:0.968454
# [407]	train-auc:0.99774	test-auc:0.968454
# [408]	train-auc:0.997765	test-auc:0.968457
# [409]	train-auc:0.997767	test-auc:0.968506
# [410]	train-auc:0.997777	test-auc:0.968519
# [411]	train-auc:0.997791	test-auc:0.968568
# [412]	train-auc:0.997804	test-auc:0.96857
# [413]	train-auc:0.997812	test-auc:0.968575
# [414]	train-auc:0.997823	test-auc:0.968601
# [415]	train-auc:0.997835	test-auc:0.968639
# [416]	train-auc:0.997846	test-auc:0.968658
# [417]	train-auc:0.997864	test-auc:0.968674
# [418]	train-auc:0.99788	test-auc:0.968693
# [419]	train-auc:0.997892	test-auc:0.968711
# [420]	train-auc:0.997904	test-auc:0.968731
# [421]	train-auc:0.997918	test-auc:0.968737
# [422]	train-auc:0.997933	test-auc:0.968738
# [423]	train-auc:0.997953	test-auc:0.968753
# [424]	train-auc:0.997959	test-auc:0.968788
# [425]	train-auc:0.997968	test-auc:0.968783
# [426]	train-auc:0.997985	test-auc:0.968785
# [427]	train-auc:0.997997	test-auc:0.968783
# [428]	train-auc:0.99801	test-auc:0.968794
# [429]	train-auc:0.998026	test-auc:0.968779
# [430]	train-auc:0.998038	test-auc:0.968769
# [431]	train-auc:0.998049	test-auc:0.968745
# [432]	train-auc:0.998057	test-auc:0.968742
# [433]	train-auc:0.998067	test-auc:0.968774
# [434]	train-auc:0.998082	test-auc:0.968765
# [435]	train-auc:0.998089	test-auc:0.968768
# [436]	train-auc:0.99809	test-auc:0.968779
# [437]	train-auc:0.998094	test-auc:0.968769
# [438]	train-auc:0.9981	test-auc:0.968783
# [439]	train-auc:0.998106	test-auc:0.968768
# [440]	train-auc:0.998119	test-auc:0.968752
# [441]	train-auc:0.998126	test-auc:0.968715
# [442]	train-auc:0.998143	test-auc:0.968707
# [443]	train-auc:0.998148	test-auc:0.968711
# [444]	train-auc:0.998166	test-auc:0.968709
# [445]	train-auc:0.998181	test-auc:0.968711
# [446]	train-auc:0.99819	test-auc:0.968708
# [447]	train-auc:0.9982	test-auc:0.968767
# [448]	train-auc:0.998214	test-auc:0.968779
# Stopping. Best iteration:
# [428]	train-auc:0.99801	test-auc:0.968794
#
# fit severe_toxic
# [0]	train-auc:0.871409	test-auc:0.888257
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.89018	test-auc:0.909784
# [2]	train-auc:0.900648	test-auc:0.922481
# [3]	train-auc:0.911925	test-auc:0.926852
# [4]	train-auc:0.915553	test-auc:0.92804
# [5]	train-auc:0.928642	test-auc:0.938473
# [6]	train-auc:0.936617	test-auc:0.939736
# [7]	train-auc:0.936928	test-auc:0.939761
# [8]	train-auc:0.940686	test-auc:0.94253
# [9]	train-auc:0.94072	test-auc:0.942707
# [10]	train-auc:0.942706	test-auc:0.944193
# [11]	train-auc:0.943948	test-auc:0.944222
# [12]	train-auc:0.946412	test-auc:0.946872
# [13]	train-auc:0.946467	test-auc:0.947
# [14]	train-auc:0.946618	test-auc:0.947062
# [15]	train-auc:0.947806	test-auc:0.94998
# [16]	train-auc:0.94966	test-auc:0.950028
# [17]	train-auc:0.950238	test-auc:0.950034
# [18]	train-auc:0.950786	test-auc:0.950111
# [19]	train-auc:0.951269	test-auc:0.950155
# [20]	train-auc:0.952806	test-auc:0.951445
# [21]	train-auc:0.952836	test-auc:0.951396
# [22]	train-auc:0.953327	test-auc:0.952882
# [23]	train-auc:0.954958	test-auc:0.952424
# [24]	train-auc:0.955393	test-auc:0.952361
# [25]	train-auc:0.96649	test-auc:0.967157
# [26]	train-auc:0.968519	test-auc:0.968872
# [27]	train-auc:0.970327	test-auc:0.970609
# [28]	train-auc:0.972017	test-auc:0.970749
# [29]	train-auc:0.973977	test-auc:0.9722
# [30]	train-auc:0.975837	test-auc:0.973832
# [31]	train-auc:0.980008	test-auc:0.975508
# [32]	train-auc:0.981699	test-auc:0.975385
# [33]	train-auc:0.981879	test-auc:0.975717
# [34]	train-auc:0.982442	test-auc:0.975847
# [35]	train-auc:0.984138	test-auc:0.975043
# [36]	train-auc:0.984243	test-auc:0.97557
# [37]	train-auc:0.985238	test-auc:0.975316
# [38]	train-auc:0.985738	test-auc:0.97521
# [39]	train-auc:0.985905	test-auc:0.975108
# [40]	train-auc:0.986132	test-auc:0.97633
# [41]	train-auc:0.986837	test-auc:0.977125
# [42]	train-auc:0.987144	test-auc:0.977077
# [43]	train-auc:0.987474	test-auc:0.976928
# [44]	train-auc:0.988064	test-auc:0.977248
# [45]	train-auc:0.988878	test-auc:0.977502
# [46]	train-auc:0.98952	test-auc:0.978606
# [47]	train-auc:0.989691	test-auc:0.978522
# [48]	train-auc:0.99141	test-auc:0.979569
# [49]	train-auc:0.991407	test-auc:0.979459
# [50]	train-auc:0.991732	test-auc:0.979427
# [51]	train-auc:0.991835	test-auc:0.979368
# [52]	train-auc:0.992735	test-auc:0.981374
# [53]	train-auc:0.993198	test-auc:0.981956
# [54]	train-auc:0.993672	test-auc:0.982296
# [55]	train-auc:0.993999	test-auc:0.983506
# [56]	train-auc:0.994315	test-auc:0.984231
# [57]	train-auc:0.994512	test-auc:0.984366
# [58]	train-auc:0.994655	test-auc:0.984412
# [59]	train-auc:0.994912	test-auc:0.984527
# [60]	train-auc:0.995153	test-auc:0.984775
# [61]	train-auc:0.995346	test-auc:0.985373
# [62]	train-auc:0.995536	test-auc:0.985911
# [63]	train-auc:0.995688	test-auc:0.986089
# [64]	train-auc:0.995837	test-auc:0.986025
# [65]	train-auc:0.995947	test-auc:0.986112
# [66]	train-auc:0.996063	test-auc:0.98613
# [67]	train-auc:0.996261	test-auc:0.986114
# [68]	train-auc:0.996411	test-auc:0.986312
# [69]	train-auc:0.996539	test-auc:0.986208
# [70]	train-auc:0.996664	test-auc:0.986204
# [71]	train-auc:0.996813	test-auc:0.98628
# [72]	train-auc:0.996881	test-auc:0.986298
# [73]	train-auc:0.996964	test-auc:0.986433
# [74]	train-auc:0.997048	test-auc:0.986454
# [75]	train-auc:0.997106	test-auc:0.98646
# [76]	train-auc:0.997158	test-auc:0.986525
# [77]	train-auc:0.9972	test-auc:0.986686
# [78]	train-auc:0.997274	test-auc:0.986747
# [79]	train-auc:0.997321	test-auc:0.98664
# [80]	train-auc:0.99741	test-auc:0.986621
# [81]	train-auc:0.997477	test-auc:0.986621
# [82]	train-auc:0.997525	test-auc:0.986686
# [83]	train-auc:0.997589	test-auc:0.986754
# [84]	train-auc:0.997638	test-auc:0.986825
# [85]	train-auc:0.997701	test-auc:0.986843
# [86]	train-auc:0.997743	test-auc:0.986902
# [87]	train-auc:0.997794	test-auc:0.986969
# [88]	train-auc:0.997825	test-auc:0.986915
# [89]	train-auc:0.997861	test-auc:0.986864
# [90]	train-auc:0.997912	test-auc:0.98686
# [91]	train-auc:0.997945	test-auc:0.986706
# [92]	train-auc:0.997996	test-auc:0.986631
# [93]	train-auc:0.998021	test-auc:0.986568
# [94]	train-auc:0.998108	test-auc:0.986701
# [95]	train-auc:0.998145	test-auc:0.986575
# [96]	train-auc:0.998172	test-auc:0.986609
# [97]	train-auc:0.998209	test-auc:0.986509
# [98]	train-auc:0.998233	test-auc:0.986453
# [99]	train-auc:0.99827	test-auc:0.986475
# [100]	train-auc:0.998295	test-auc:0.986502
# [101]	train-auc:0.99831	test-auc:0.986522
# [102]	train-auc:0.99833	test-auc:0.986479
# [103]	train-auc:0.998362	test-auc:0.986572
# [104]	train-auc:0.998406	test-auc:0.986633
# [105]	train-auc:0.998425	test-auc:0.986618
# [106]	train-auc:0.998449	test-auc:0.986654
# [107]	train-auc:0.998488	test-auc:0.986478
# Stopping. Best iteration:
# [87]	train-auc:0.997794	test-auc:0.986969
#
# fit obscene
# [0]	train-auc:0.82781	test-auc:0.819579
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.865995	test-auc:0.860079
# [2]	train-auc:0.870533	test-auc:0.864317
# [3]	train-auc:0.870911	test-auc:0.86463
# [4]	train-auc:0.880963	test-auc:0.877787
# [5]	train-auc:0.887178	test-auc:0.885939
# [6]	train-auc:0.888449	test-auc:0.88652
# [7]	train-auc:0.890518	test-auc:0.88734
# [8]	train-auc:0.900311	test-auc:0.898287
# [9]	train-auc:0.903751	test-auc:0.901165
# [10]	train-auc:0.904457	test-auc:0.90146
# [11]	train-auc:0.907092	test-auc:0.90237
# [12]	train-auc:0.908708	test-auc:0.905263
# [13]	train-auc:0.917688	test-auc:0.912697
# [14]	train-auc:0.919433	test-auc:0.914411
# [15]	train-auc:0.937453	test-auc:0.92753
# [16]	train-auc:0.937432	test-auc:0.928158
# [17]	train-auc:0.943014	test-auc:0.933763
# [18]	train-auc:0.945869	test-auc:0.935061
# [19]	train-auc:0.94862	test-auc:0.938043
# [20]	train-auc:0.950236	test-auc:0.939187
# [21]	train-auc:0.950844	test-auc:0.940019
# [22]	train-auc:0.953997	test-auc:0.945087
# [23]	train-auc:0.955206	test-auc:0.947098
# [24]	train-auc:0.963646	test-auc:0.955081
# [25]	train-auc:0.969516	test-auc:0.959808
# [26]	train-auc:0.972071	test-auc:0.962882
# [27]	train-auc:0.97268	test-auc:0.963317
# [28]	train-auc:0.972548	test-auc:0.962918
# [29]	train-auc:0.973351	test-auc:0.963544
# [30]	train-auc:0.974265	test-auc:0.964153
# [31]	train-auc:0.975808	test-auc:0.966293
# [32]	train-auc:0.976531	test-auc:0.966788
# [33]	train-auc:0.977162	test-auc:0.967273
# [34]	train-auc:0.977747	test-auc:0.967766
# [35]	train-auc:0.978627	test-auc:0.968742
# [36]	train-auc:0.979264	test-auc:0.969335
# [37]	train-auc:0.980637	test-auc:0.969973
# [38]	train-auc:0.981922	test-auc:0.970581
# [39]	train-auc:0.982528	test-auc:0.9705
# [40]	train-auc:0.983097	test-auc:0.971394
# [41]	train-auc:0.983748	test-auc:0.972194
# [42]	train-auc:0.984069	test-auc:0.972129
# [43]	train-auc:0.984524	test-auc:0.97257
# [44]	train-auc:0.984655	test-auc:0.972771
# [45]	train-auc:0.985202	test-auc:0.973237
# [46]	train-auc:0.985817	test-auc:0.974162
# [47]	train-auc:0.986488	test-auc:0.974268
# [48]	train-auc:0.986899	test-auc:0.974618
# [49]	train-auc:0.987469	test-auc:0.974859
# [50]	train-auc:0.987876	test-auc:0.975238
# [51]	train-auc:0.987902	test-auc:0.975223
# [52]	train-auc:0.988118	test-auc:0.975386
# [53]	train-auc:0.988725	test-auc:0.975833
# [54]	train-auc:0.988897	test-auc:0.976158
# [55]	train-auc:0.989044	test-auc:0.976363
# [56]	train-auc:0.989508	test-auc:0.976605
# [57]	train-auc:0.989622	test-auc:0.97698
# [58]	train-auc:0.989822	test-auc:0.977166
# [59]	train-auc:0.990096	test-auc:0.97709
# [60]	train-auc:0.990461	test-auc:0.977372
# [61]	train-auc:0.990659	test-auc:0.977622
# [62]	train-auc:0.990963	test-auc:0.977575
# [63]	train-auc:0.991293	test-auc:0.977654
# [64]	train-auc:0.991614	test-auc:0.977877
# [65]	train-auc:0.991732	test-auc:0.978087
# [66]	train-auc:0.991883	test-auc:0.978153
# [67]	train-auc:0.992012	test-auc:0.978369
# [68]	train-auc:0.992249	test-auc:0.978574
# [69]	train-auc:0.992421	test-auc:0.978773
# [70]	train-auc:0.992675	test-auc:0.978902
# [71]	train-auc:0.992828	test-auc:0.97901
# [72]	train-auc:0.992973	test-auc:0.978999
# [73]	train-auc:0.993094	test-auc:0.979133
# [74]	train-auc:0.993174	test-auc:0.979132
# [75]	train-auc:0.993254	test-auc:0.979162
# [76]	train-auc:0.993446	test-auc:0.97923
# [77]	train-auc:0.993546	test-auc:0.979352
# [78]	train-auc:0.993599	test-auc:0.979529
# [79]	train-auc:0.993654	test-auc:0.979664
# [80]	train-auc:0.993764	test-auc:0.979657
# [81]	train-auc:0.993935	test-auc:0.979666
# [82]	train-auc:0.994001	test-auc:0.97976
# [83]	train-auc:0.99406	test-auc:0.979956
# [84]	train-auc:0.994179	test-auc:0.979996
# [85]	train-auc:0.994272	test-auc:0.980083
# [86]	train-auc:0.994331	test-auc:0.980245
# [87]	train-auc:0.994405	test-auc:0.980352
# [88]	train-auc:0.99453	test-auc:0.980363
# [89]	train-auc:0.994672	test-auc:0.980551
# [90]	train-auc:0.99472	test-auc:0.980601
# [91]	train-auc:0.994799	test-auc:0.980744
# [92]	train-auc:0.994865	test-auc:0.981017
# [93]	train-auc:0.994899	test-auc:0.981099
# [94]	train-auc:0.994992	test-auc:0.981153
# [95]	train-auc:0.99506	test-auc:0.98125
# [96]	train-auc:0.995148	test-auc:0.981315
# [97]	train-auc:0.995243	test-auc:0.98133
# [98]	train-auc:0.995283	test-auc:0.981436
# [99]	train-auc:0.995364	test-auc:0.981585
# [100]	train-auc:0.995436	test-auc:0.981746
# [101]	train-auc:0.995511	test-auc:0.981758
# [102]	train-auc:0.99555	test-auc:0.981827
# [103]	train-auc:0.995622	test-auc:0.981885
# [104]	train-auc:0.995675	test-auc:0.981929
# [105]	train-auc:0.995798	test-auc:0.981979
# [106]	train-auc:0.995873	test-auc:0.982013
# [107]	train-auc:0.995933	test-auc:0.982133
# [108]	train-auc:0.996031	test-auc:0.982335
# [109]	train-auc:0.996072	test-auc:0.982435
# [110]	train-auc:0.996137	test-auc:0.982493
# [111]	train-auc:0.996228	test-auc:0.982563
# [112]	train-auc:0.996252	test-auc:0.98278
# [113]	train-auc:0.996292	test-auc:0.982929
# [114]	train-auc:0.996327	test-auc:0.982922
# [115]	train-auc:0.996384	test-auc:0.982975
# [116]	train-auc:0.99642	test-auc:0.983009
# [117]	train-auc:0.99645	test-auc:0.983083
# [118]	train-auc:0.996564	test-auc:0.983171
# [119]	train-auc:0.996584	test-auc:0.983166
# [120]	train-auc:0.996623	test-auc:0.983207
# [121]	train-auc:0.996648	test-auc:0.983207
# [122]	train-auc:0.996725	test-auc:0.983246
# [123]	train-auc:0.996763	test-auc:0.983281
# [124]	train-auc:0.996777	test-auc:0.983283
# [125]	train-auc:0.99686	test-auc:0.98332
# [126]	train-auc:0.996877	test-auc:0.983368
# [127]	train-auc:0.996908	test-auc:0.983438
# [128]	train-auc:0.996957	test-auc:0.983456
# [129]	train-auc:0.996992	test-auc:0.983496
# [130]	train-auc:0.997018	test-auc:0.983463
# [131]	train-auc:0.997069	test-auc:0.983389
# [132]	train-auc:0.997089	test-auc:0.983469
# [133]	train-auc:0.997121	test-auc:0.983504
# [134]	train-auc:0.997139	test-auc:0.983512
# [135]	train-auc:0.997165	test-auc:0.983525
# [136]	train-auc:0.997202	test-auc:0.983521
# [137]	train-auc:0.997233	test-auc:0.983612
# [138]	train-auc:0.997261	test-auc:0.983634
# [139]	train-auc:0.997303	test-auc:0.983691
# [140]	train-auc:0.997358	test-auc:0.983777
# [141]	train-auc:0.997398	test-auc:0.98377
# [142]	train-auc:0.997427	test-auc:0.983797
# [143]	train-auc:0.997524	test-auc:0.983995
# [144]	train-auc:0.997569	test-auc:0.984053
# [145]	train-auc:0.997647	test-auc:0.984152
# [146]	train-auc:0.997667	test-auc:0.984126
# [147]	train-auc:0.997679	test-auc:0.984103
# [148]	train-auc:0.997698	test-auc:0.984136
# [149]	train-auc:0.997706	test-auc:0.984182
# [150]	train-auc:0.997739	test-auc:0.984302
# [151]	train-auc:0.997794	test-auc:0.984308
# [152]	train-auc:0.997813	test-auc:0.984312
# [153]	train-auc:0.997833	test-auc:0.984341
# [154]	train-auc:0.997854	test-auc:0.984333
# [155]	train-auc:0.997885	test-auc:0.98436
# [156]	train-auc:0.997904	test-auc:0.984386
# [157]	train-auc:0.997944	test-auc:0.984431
# [158]	train-auc:0.997964	test-auc:0.984442
# [159]	train-auc:0.997986	test-auc:0.984511
# [160]	train-auc:0.998009	test-auc:0.984455
# [161]	train-auc:0.998037	test-auc:0.984466
# [162]	train-auc:0.99807	test-auc:0.984499
# [163]	train-auc:0.998097	test-auc:0.9845
# [164]	train-auc:0.998121	test-auc:0.98448
# [165]	train-auc:0.998138	test-auc:0.984549
# [166]	train-auc:0.998162	test-auc:0.984572
# [167]	train-auc:0.998208	test-auc:0.984571
# [168]	train-auc:0.998224	test-auc:0.984554
# [169]	train-auc:0.998248	test-auc:0.984601
# [170]	train-auc:0.998261	test-auc:0.984558
# [171]	train-auc:0.998271	test-auc:0.984586
# [172]	train-auc:0.998279	test-auc:0.984582
# [173]	train-auc:0.998295	test-auc:0.984585
# [174]	train-auc:0.998309	test-auc:0.9846
# [175]	train-auc:0.99834	test-auc:0.984621
# [176]	train-auc:0.998369	test-auc:0.984622
# [177]	train-auc:0.998384	test-auc:0.984644
# [178]	train-auc:0.998415	test-auc:0.984658
# [179]	train-auc:0.998437	test-auc:0.984679
# [180]	train-auc:0.998463	test-auc:0.984558
# [181]	train-auc:0.998483	test-auc:0.984534
# [182]	train-auc:0.998496	test-auc:0.984564
# [183]	train-auc:0.998505	test-auc:0.98457
# [184]	train-auc:0.998517	test-auc:0.984597
# [185]	train-auc:0.998521	test-auc:0.984589
# [186]	train-auc:0.998562	test-auc:0.9846
# [187]	train-auc:0.998582	test-auc:0.984493
# [188]	train-auc:0.998588	test-auc:0.98459
# [189]	train-auc:0.998607	test-auc:0.98459
# [190]	train-auc:0.998616	test-auc:0.984583
# [191]	train-auc:0.998631	test-auc:0.98458
# [192]	train-auc:0.998647	test-auc:0.98454
# [193]	train-auc:0.998666	test-auc:0.984506
# [194]	train-auc:0.998676	test-auc:0.984556
# [195]	train-auc:0.998689	test-auc:0.984582
# [196]	train-auc:0.998691	test-auc:0.98468
# [197]	train-auc:0.99871	test-auc:0.984743
# [198]	train-auc:0.998724	test-auc:0.984779
# [199]	train-auc:0.998743	test-auc:0.984728
# [200]	train-auc:0.998756	test-auc:0.984728
# [201]	train-auc:0.998764	test-auc:0.984725
# [202]	train-auc:0.998777	test-auc:0.984773
# [203]	train-auc:0.998802	test-auc:0.984736
# [204]	train-auc:0.99881	test-auc:0.984727
# [205]	train-auc:0.998827	test-auc:0.984718
# [206]	train-auc:0.998845	test-auc:0.984669
# [207]	train-auc:0.998855	test-auc:0.984721
# [208]	train-auc:0.998862	test-auc:0.984713
# [209]	train-auc:0.998879	test-auc:0.984795
# [210]	train-auc:0.998904	test-auc:0.984869
# [211]	train-auc:0.998917	test-auc:0.984881
# [212]	train-auc:0.998926	test-auc:0.984924
# [213]	train-auc:0.998946	test-auc:0.984939
# [214]	train-auc:0.998958	test-auc:0.98499
# [215]	train-auc:0.998973	test-auc:0.984997
# [216]	train-auc:0.998982	test-auc:0.985028
# [217]	train-auc:0.998993	test-auc:0.985035
# [218]	train-auc:0.999008	test-auc:0.985059
# [219]	train-auc:0.999018	test-auc:0.985098
# [220]	train-auc:0.99902	test-auc:0.985118
# [221]	train-auc:0.999023	test-auc:0.985134
# [222]	train-auc:0.999028	test-auc:0.98518
# [223]	train-auc:0.999035	test-auc:0.985196
# [224]	train-auc:0.999046	test-auc:0.985227
# [225]	train-auc:0.999051	test-auc:0.985249
# [226]	train-auc:0.999059	test-auc:0.985254
# [227]	train-auc:0.999066	test-auc:0.985228
# [228]	train-auc:0.999077	test-auc:0.985237
# [229]	train-auc:0.999094	test-auc:0.985169
# [230]	train-auc:0.999101	test-auc:0.985121
# [231]	train-auc:0.999105	test-auc:0.985177
# [232]	train-auc:0.999114	test-auc:0.985224
# [233]	train-auc:0.999129	test-auc:0.985136
# [234]	train-auc:0.999134	test-auc:0.98516
# [235]	train-auc:0.999141	test-auc:0.985162
# [236]	train-auc:0.999152	test-auc:0.985157
# [237]	train-auc:0.99916	test-auc:0.985218
# [238]	train-auc:0.999164	test-auc:0.985239
# [239]	train-auc:0.99917	test-auc:0.98524
# [240]	train-auc:0.999184	test-auc:0.985209
# [241]	train-auc:0.999193	test-auc:0.985219
# [242]	train-auc:0.999196	test-auc:0.98524
# [243]	train-auc:0.999201	test-auc:0.985312
# [244]	train-auc:0.999208	test-auc:0.985343
# [245]	train-auc:0.999212	test-auc:0.985385
# [246]	train-auc:0.999216	test-auc:0.985381
# [247]	train-auc:0.99923	test-auc:0.985368
# [248]	train-auc:0.999241	test-auc:0.985335
# [249]	train-auc:0.999249	test-auc:0.98532
# [250]	train-auc:0.99925	test-auc:0.98532
# [251]	train-auc:0.999255	test-auc:0.985321
# [252]	train-auc:0.999263	test-auc:0.985336
# [253]	train-auc:0.999281	test-auc:0.985336
# [254]	train-auc:0.999285	test-auc:0.985365
# [255]	train-auc:0.999295	test-auc:0.985378
# [256]	train-auc:0.999301	test-auc:0.985407
# [257]	train-auc:0.99931	test-auc:0.985389
# [258]	train-auc:0.999319	test-auc:0.985393
# [259]	train-auc:0.999321	test-auc:0.985429
# [260]	train-auc:0.999326	test-auc:0.985434
# [261]	train-auc:0.999339	test-auc:0.985383
# [262]	train-auc:0.999345	test-auc:0.98534
# [263]	train-auc:0.999348	test-auc:0.98538
# [264]	train-auc:0.999351	test-auc:0.985401
# [265]	train-auc:0.999357	test-auc:0.985403
# [266]	train-auc:0.999361	test-auc:0.985399
# [267]	train-auc:0.999369	test-auc:0.985426
# [268]	train-auc:0.999378	test-auc:0.985426
# [269]	train-auc:0.999381	test-auc:0.985431
# [270]	train-auc:0.999395	test-auc:0.985458
# [271]	train-auc:0.999398	test-auc:0.985458
# [272]	train-auc:0.99941	test-auc:0.985487
# [273]	train-auc:0.999415	test-auc:0.985514
# [274]	train-auc:0.999419	test-auc:0.985524
# [275]	train-auc:0.999424	test-auc:0.98555
# [276]	train-auc:0.999428	test-auc:0.985577
# [277]	train-auc:0.999436	test-auc:0.985558
# [278]	train-auc:0.999439	test-auc:0.985548
# [279]	train-auc:0.999445	test-auc:0.98555
# [280]	train-auc:0.999448	test-auc:0.985554
# [281]	train-auc:0.99945	test-auc:0.985577
# [282]	train-auc:0.999455	test-auc:0.985606
# [283]	train-auc:0.999459	test-auc:0.985645
# [284]	train-auc:0.999462	test-auc:0.985614
# [285]	train-auc:0.999465	test-auc:0.985617
# [286]	train-auc:0.99947	test-auc:0.985624
# [287]	train-auc:0.999474	test-auc:0.985575
# [288]	train-auc:0.999484	test-auc:0.985656
# [289]	train-auc:0.99949	test-auc:0.985691
# [290]	train-auc:0.999495	test-auc:0.985641
# [291]	train-auc:0.999498	test-auc:0.985684
# [292]	train-auc:0.999504	test-auc:0.985713
# [293]	train-auc:0.999508	test-auc:0.985752
# [294]	train-auc:0.999512	test-auc:0.985766
# [295]	train-auc:0.999516	test-auc:0.98576
# [296]	train-auc:0.999519	test-auc:0.985761
# [297]	train-auc:0.999522	test-auc:0.98576
# [298]	train-auc:0.999527	test-auc:0.985694
# [299]	train-auc:0.99953	test-auc:0.98572
# [300]	train-auc:0.999532	test-auc:0.985698
# [301]	train-auc:0.999534	test-auc:0.985718
# [302]	train-auc:0.999538	test-auc:0.985753
# [303]	train-auc:0.999543	test-auc:0.985727
# [304]	train-auc:0.999546	test-auc:0.98575
# [305]	train-auc:0.99955	test-auc:0.985762
# [306]	train-auc:0.999553	test-auc:0.985775
# [307]	train-auc:0.999557	test-auc:0.985758
# [308]	train-auc:0.999561	test-auc:0.98574
# [309]	train-auc:0.999564	test-auc:0.98571
# [310]	train-auc:0.999567	test-auc:0.985765
# [311]	train-auc:0.999571	test-auc:0.985767
# [312]	train-auc:0.999574	test-auc:0.985768
# [313]	train-auc:0.99958	test-auc:0.985754
# [314]	train-auc:0.999584	test-auc:0.985772
# [315]	train-auc:0.999594	test-auc:0.985777
# [316]	train-auc:0.999602	test-auc:0.985811
# [317]	train-auc:0.999606	test-auc:0.985831
# [318]	train-auc:0.999614	test-auc:0.985874
# [319]	train-auc:0.999617	test-auc:0.985868
# [320]	train-auc:0.999618	test-auc:0.985871
# [321]	train-auc:0.999623	test-auc:0.985923
# [322]	train-auc:0.99963	test-auc:0.98596
# [323]	train-auc:0.999632	test-auc:0.985985
# [324]	train-auc:0.999635	test-auc:0.986012
# [325]	train-auc:0.999637	test-auc:0.985997
# [326]	train-auc:0.999639	test-auc:0.98601
# [327]	train-auc:0.999644	test-auc:0.985982
# [328]	train-auc:0.999645	test-auc:0.985919
# [329]	train-auc:0.999651	test-auc:0.985935
# [330]	train-auc:0.999654	test-auc:0.985931
# [331]	train-auc:0.999657	test-auc:0.985852
# [332]	train-auc:0.999659	test-auc:0.985876
# [333]	train-auc:0.999662	test-auc:0.98586
# [334]	train-auc:0.999666	test-auc:0.985875
# [335]	train-auc:0.999669	test-auc:0.985861
# [336]	train-auc:0.999673	test-auc:0.985807
# [337]	train-auc:0.999676	test-auc:0.9858
# [338]	train-auc:0.999679	test-auc:0.985817
# [339]	train-auc:0.999681	test-auc:0.98581
# [340]	train-auc:0.999686	test-auc:0.985829
# [341]	train-auc:0.999689	test-auc:0.985831
# [342]	train-auc:0.999691	test-auc:0.985825
# [343]	train-auc:0.999695	test-auc:0.985836
# [344]	train-auc:0.999699	test-auc:0.985861
# Stopping. Best iteration:
# [324]	train-auc:0.999635	test-auc:0.986012
#
# fit threat
# [0]	train-auc:0.739421	test-auc:0.751615
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.759413	test-auc:0.762938
# [2]	train-auc:0.794068	test-auc:0.796303
# [3]	train-auc:0.796827	test-auc:0.802195
# [4]	train-auc:0.813134	test-auc:0.824376
# [5]	train-auc:0.824759	test-auc:0.846148
# [6]	train-auc:0.826144	test-auc:0.845799
# [7]	train-auc:0.837884	test-auc:0.850829
# [8]	train-auc:0.837859	test-auc:0.850519
# [9]	train-auc:0.849445	test-auc:0.855921
# [10]	train-auc:0.879509	test-auc:0.865696
# [11]	train-auc:0.889881	test-auc:0.87635
# [12]	train-auc:0.891193	test-auc:0.886559
# [13]	train-auc:0.894036	test-auc:0.886904
# [14]	train-auc:0.898642	test-auc:0.893479
# [15]	train-auc:0.901057	test-auc:0.897597
# [16]	train-auc:0.90283	test-auc:0.89749
# [17]	train-auc:0.902973	test-auc:0.897849
# [18]	train-auc:0.905595	test-auc:0.897831
# [19]	train-auc:0.920996	test-auc:0.901642
# [20]	train-auc:0.921075	test-auc:0.90156
# [21]	train-auc:0.924694	test-auc:0.902173
# [22]	train-auc:0.925338	test-auc:0.90687
# [23]	train-auc:0.930435	test-auc:0.907049
# [24]	train-auc:0.930348	test-auc:0.907229
# [25]	train-auc:0.937727	test-auc:0.915156
# [26]	train-auc:0.939434	test-auc:0.915132
# [27]	train-auc:0.956896	test-auc:0.929453
# [28]	train-auc:0.961209	test-auc:0.929634
# [29]	train-auc:0.968407	test-auc:0.929146
# [30]	train-auc:0.972897	test-auc:0.930635
# [31]	train-auc:0.97685	test-auc:0.930124
# [32]	train-auc:0.977225	test-auc:0.929972
# [33]	train-auc:0.977651	test-auc:0.93353
# [34]	train-auc:0.978971	test-auc:0.933373
# [35]	train-auc:0.980182	test-auc:0.933139
# [36]	train-auc:0.980031	test-auc:0.933647
# [37]	train-auc:0.981478	test-auc:0.938827
# [38]	train-auc:0.981722	test-auc:0.937594
# [39]	train-auc:0.983107	test-auc:0.942317
# [40]	train-auc:0.987926	test-auc:0.945419
# [41]	train-auc:0.987834	test-auc:0.945381
# [42]	train-auc:0.98836	test-auc:0.944724
# [43]	train-auc:0.989083	test-auc:0.947724
# [44]	train-auc:0.988948	test-auc:0.947456
# [45]	train-auc:0.989399	test-auc:0.946021
# [46]	train-auc:0.989373	test-auc:0.946124
# [47]	train-auc:0.989838	test-auc:0.945973
# [48]	train-auc:0.989946	test-auc:0.948037
# [49]	train-auc:0.991085	test-auc:0.959109
# [50]	train-auc:0.991024	test-auc:0.959228
# [51]	train-auc:0.991282	test-auc:0.9574
# [52]	train-auc:0.992787	test-auc:0.956845
# [53]	train-auc:0.993519	test-auc:0.956327
# [54]	train-auc:0.993567	test-auc:0.955046
# [55]	train-auc:0.994299	test-auc:0.956081
# [56]	train-auc:0.994265	test-auc:0.955691
# [57]	train-auc:0.995079	test-auc:0.954474
# [58]	train-auc:0.996339	test-auc:0.952998
# [59]	train-auc:0.996693	test-auc:0.9544
# [60]	train-auc:0.997311	test-auc:0.956282
# [61]	train-auc:0.997843	test-auc:0.95357
# [62]	train-auc:0.997895	test-auc:0.952498
# [63]	train-auc:0.998056	test-auc:0.951153
# [64]	train-auc:0.998462	test-auc:0.954675
# [65]	train-auc:0.998731	test-auc:0.956042
# [66]	train-auc:0.998886	test-auc:0.956666
# [67]	train-auc:0.998893	test-auc:0.956696
# [68]	train-auc:0.998911	test-auc:0.956134
# [69]	train-auc:0.998978	test-auc:0.955104
# [70]	train-auc:0.999002	test-auc:0.955361
# Stopping. Best iteration:
# [50]	train-auc:0.991024	test-auc:0.959228
#
# fit insult
# [0]	train-auc:0.792172	test-auc:0.796348
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.812818	test-auc:0.820003
# [2]	train-auc:0.820807	test-auc:0.827335
# [3]	train-auc:0.823974	test-auc:0.829144
# [4]	train-auc:0.824475	test-auc:0.829661
# [5]	train-auc:0.828728	test-auc:0.833803
# [6]	train-auc:0.887401	test-auc:0.882725
# [7]	train-auc:0.888684	test-auc:0.883251
# [8]	train-auc:0.889941	test-auc:0.884452
# [9]	train-auc:0.892577	test-auc:0.886316
# [10]	train-auc:0.895545	test-auc:0.888431
# [11]	train-auc:0.912987	test-auc:0.902495
# [12]	train-auc:0.920054	test-auc:0.910878
# [13]	train-auc:0.922918	test-auc:0.913215
# [14]	train-auc:0.926307	test-auc:0.915202
# [15]	train-auc:0.9292	test-auc:0.917604
# [16]	train-auc:0.929933	test-auc:0.917994
# [17]	train-auc:0.933001	test-auc:0.919118
# [18]	train-auc:0.940009	test-auc:0.926199
# [19]	train-auc:0.93999	test-auc:0.92622
# [20]	train-auc:0.942789	test-auc:0.928392
# [21]	train-auc:0.945088	test-auc:0.930119
# [22]	train-auc:0.947398	test-auc:0.933375
# [23]	train-auc:0.949245	test-auc:0.93429
# [24]	train-auc:0.94974	test-auc:0.93565
# [25]	train-auc:0.950915	test-auc:0.937616
# [26]	train-auc:0.953857	test-auc:0.941454
# [27]	train-auc:0.95523	test-auc:0.942852
# [28]	train-auc:0.956166	test-auc:0.943062
# [29]	train-auc:0.957169	test-auc:0.943827
# [30]	train-auc:0.957807	test-auc:0.944349
# [31]	train-auc:0.959918	test-auc:0.94639
# [32]	train-auc:0.961427	test-auc:0.947641
# [33]	train-auc:0.963427	test-auc:0.949193
# [34]	train-auc:0.964296	test-auc:0.949947
# [35]	train-auc:0.964921	test-auc:0.950565
# [36]	train-auc:0.965821	test-auc:0.95189
# [37]	train-auc:0.966538	test-auc:0.952269
# [38]	train-auc:0.967454	test-auc:0.953314
# [39]	train-auc:0.968513	test-auc:0.953605
# [40]	train-auc:0.969299	test-auc:0.954301
# [41]	train-auc:0.970324	test-auc:0.9547
# [42]	train-auc:0.971362	test-auc:0.955611
# [43]	train-auc:0.971997	test-auc:0.956698
# [44]	train-auc:0.972788	test-auc:0.956915
# [45]	train-auc:0.973504	test-auc:0.957045
# [46]	train-auc:0.974229	test-auc:0.957536
# [47]	train-auc:0.97479	test-auc:0.957788
# [48]	train-auc:0.975318	test-auc:0.958146
# [49]	train-auc:0.975717	test-auc:0.958268
# [50]	train-auc:0.976374	test-auc:0.958629
# [51]	train-auc:0.976826	test-auc:0.958767
# [52]	train-auc:0.977178	test-auc:0.959034
# [53]	train-auc:0.977475	test-auc:0.959269
# [54]	train-auc:0.977925	test-auc:0.959599
# [55]	train-auc:0.978313	test-auc:0.960072
# [56]	train-auc:0.978718	test-auc:0.960141
# [57]	train-auc:0.979089	test-auc:0.960409
# [58]	train-auc:0.979568	test-auc:0.960647
# [59]	train-auc:0.979922	test-auc:0.96099
# [60]	train-auc:0.980299	test-auc:0.961046
# [61]	train-auc:0.980602	test-auc:0.961364
# [62]	train-auc:0.981014	test-auc:0.961747
# [63]	train-auc:0.981246	test-auc:0.961912
# [64]	train-auc:0.981449	test-auc:0.962146
# [65]	train-auc:0.981989	test-auc:0.962203
# [66]	train-auc:0.98229	test-auc:0.962364
# [67]	train-auc:0.982782	test-auc:0.962738
# [68]	train-auc:0.983142	test-auc:0.962892
# [69]	train-auc:0.983253	test-auc:0.963282
# [70]	train-auc:0.983522	test-auc:0.963627
# [71]	train-auc:0.983723	test-auc:0.963918
# [72]	train-auc:0.983992	test-auc:0.964069
# [73]	train-auc:0.984261	test-auc:0.964431
# [74]	train-auc:0.984411	test-auc:0.964551
# [75]	train-auc:0.98468	test-auc:0.964825
# [76]	train-auc:0.984762	test-auc:0.965067
# [77]	train-auc:0.984954	test-auc:0.965332
# [78]	train-auc:0.98512	test-auc:0.965477
# [79]	train-auc:0.985365	test-auc:0.965753
# [80]	train-auc:0.985687	test-auc:0.966129
# [81]	train-auc:0.9859	test-auc:0.966285
# [82]	train-auc:0.986034	test-auc:0.966486
# [83]	train-auc:0.986355	test-auc:0.966655
# [84]	train-auc:0.986609	test-auc:0.966867
# [85]	train-auc:0.986895	test-auc:0.966991
# [86]	train-auc:0.987138	test-auc:0.967116
# [87]	train-auc:0.987446	test-auc:0.967468
# [88]	train-auc:0.987552	test-auc:0.967609
# [89]	train-auc:0.987683	test-auc:0.967717
# [90]	train-auc:0.987813	test-auc:0.967842
# [91]	train-auc:0.988089	test-auc:0.968056
# [92]	train-auc:0.988294	test-auc:0.968208
# [93]	train-auc:0.988409	test-auc:0.968383
# [94]	train-auc:0.988566	test-auc:0.968758
# [95]	train-auc:0.988771	test-auc:0.968924
# [96]	train-auc:0.988944	test-auc:0.968941
# [97]	train-auc:0.989112	test-auc:0.969122
# [98]	train-auc:0.989238	test-auc:0.969231
# [99]	train-auc:0.989365	test-auc:0.969478
# [100]	train-auc:0.989467	test-auc:0.969433
# [101]	train-auc:0.989612	test-auc:0.969537
# [102]	train-auc:0.989805	test-auc:0.969746
# [103]	train-auc:0.989935	test-auc:0.969857
# [104]	train-auc:0.99017	test-auc:0.969999
# [105]	train-auc:0.990244	test-auc:0.970116
# [106]	train-auc:0.990335	test-auc:0.970154
# [107]	train-auc:0.990494	test-auc:0.970291
# [108]	train-auc:0.990613	test-auc:0.970401
# [109]	train-auc:0.990736	test-auc:0.970544
# [110]	train-auc:0.990823	test-auc:0.970535
# [111]	train-auc:0.9909	test-auc:0.970603
# [112]	train-auc:0.99102	test-auc:0.970705
# [113]	train-auc:0.991131	test-auc:0.970766
# [114]	train-auc:0.991217	test-auc:0.970968
# [115]	train-auc:0.991313	test-auc:0.971176
# [116]	train-auc:0.991404	test-auc:0.971352
# [117]	train-auc:0.991476	test-auc:0.971469
# [118]	train-auc:0.991523	test-auc:0.971568
# [119]	train-auc:0.991651	test-auc:0.971656
# [120]	train-auc:0.991793	test-auc:0.971715
# [121]	train-auc:0.991874	test-auc:0.9718
# [122]	train-auc:0.991971	test-auc:0.971932
# [123]	train-auc:0.992061	test-auc:0.972116
# [124]	train-auc:0.992118	test-auc:0.972104
# [125]	train-auc:0.992238	test-auc:0.972125
# [126]	train-auc:0.992285	test-auc:0.972148
# [127]	train-auc:0.992324	test-auc:0.972261
# [128]	train-auc:0.99243	test-auc:0.972365
# [129]	train-auc:0.992478	test-auc:0.972364
# [130]	train-auc:0.992546	test-auc:0.972489
# [131]	train-auc:0.992598	test-auc:0.972527
# [132]	train-auc:0.992703	test-auc:0.972642
# [133]	train-auc:0.992768	test-auc:0.972781
# [134]	train-auc:0.992807	test-auc:0.972758
# [135]	train-auc:0.9929	test-auc:0.972828
# [136]	train-auc:0.992949	test-auc:0.972901
# ...
# [168]	train-auc:0.994786	test-auc:0.974574
# [169]	train-auc:0.994819	test-auc:0.974663
# [170]	train-auc:0.994871	test-auc:0.97475
# [171]	train-auc:0.994892	test-auc:0.974786
# [172]	train-auc:0.994927	test-auc:0.974725
# [173]	train-auc:0.994983	test-auc:0.974779
# [174]	train-auc:0.995019	test-auc:0.974832
# [175]	train-auc:0.995056	test-auc:0.974918
# [176]	train-auc:0.995087	test-auc:0.974947
# [177]	train-auc:0.99512	test-auc:0.975038
# [178]	train-auc:0.995136	test-auc:0.975057
# [179]	train-auc:0.99519	test-auc:0.975101
# [180]	train-auc:0.99523	test-auc:0.975151
# [181]	train-auc:0.995256	test-auc:0.975184
# [182]	train-auc:0.995289	test-auc:0.975344
# [183]	train-auc:0.99531	test-auc:0.975372
# [184]	train-auc:0.995352	test-auc:0.975374
# [185]	train-auc:0.995387	test-auc:0.97538
# [186]	train-auc:0.995427	test-auc:0.975353
# [187]	train-auc:0.995466	test-auc:0.975423
# [188]	train-auc:0.99548	test-auc:0.975462
# [189]	train-auc:0.99549	test-auc:0.975463
# [190]	train-auc:0.995546	test-auc:0.975425
# [191]	train-auc:0.995568	test-auc:0.975427
# [192]	train-auc:0.995604	test-auc:0.97544
# [193]	train-auc:0.995646	test-auc:0.975429
# [194]	train-auc:0.995696	test-auc:0.975309
# [195]	train-auc:0.995736	test-auc:0.975375
# [196]	train-auc:0.995769	test-auc:0.975359
# [197]	train-auc:0.995805	test-auc:0.97537
# [198]	train-auc:0.995825	test-auc:0.975365
# [199]	train-auc:0.995864	test-auc:0.975432
# [200]	train-auc:0.995897	test-auc:0.975442
# [201]	train-auc:0.995926	test-auc:0.975554
# [202]	train-auc:0.995959	test-auc:0.975602
# [203]	train-auc:0.995985	test-auc:0.975674
# [204]	train-auc:0.996002	test-auc:0.975685
# [205]	train-auc:0.996021	test-auc:0.975807
# [206]	train-auc:0.996059	test-auc:0.975823
# [207]	train-auc:0.996117	test-auc:0.975832
# [208]	train-auc:0.996144	test-auc:0.975869
# [209]	train-auc:0.996174	test-auc:0.975876
# [210]	train-auc:0.996214	test-auc:0.975892
# [211]	train-auc:0.996241	test-auc:0.975895
# [212]	train-auc:0.996281	test-auc:0.975945
# [213]	train-auc:0.996329	test-auc:0.97594
# [214]	train-auc:0.996371	test-auc:0.975944
# [215]	train-auc:0.996403	test-auc:0.97599
# [216]	train-auc:0.996423	test-auc:0.976025
# [217]	train-auc:0.996451	test-auc:0.976059
# [218]	train-auc:0.996474	test-auc:0.976082
# [219]	train-auc:0.996495	test-auc:0.976058
# [220]	train-auc:0.996516	test-auc:0.976122
# [221]	train-auc:0.996561	test-auc:0.976269
# [222]	train-auc:0.99658	test-auc:0.976268
# [223]	train-auc:0.996597	test-auc:0.976258
# [224]	train-auc:0.996612	test-auc:0.976277
# [225]	train-auc:0.996651	test-auc:0.976337
# [226]	train-auc:0.996672	test-auc:0.97633
# [227]	train-auc:0.996711	test-auc:0.976374
# [228]	train-auc:0.996747	test-auc:0.976355
# [229]	train-auc:0.996778	test-auc:0.976382
# [230]	train-auc:0.996804	test-auc:0.976355
# [231]	train-auc:0.996839	test-auc:0.97633
# [232]	train-auc:0.996875	test-auc:0.976342
# [233]	train-auc:0.996889	test-auc:0.976422
# [234]	train-auc:0.996909	test-auc:0.976454
# [235]	train-auc:0.996941	test-auc:0.976392
# [236]	train-auc:0.996966	test-auc:0.976406
# [237]	train-auc:0.996998	test-auc:0.976545
# [238]	train-auc:0.997021	test-auc:0.976582
# [239]	train-auc:0.997034	test-auc:0.97651
# [240]	train-auc:0.997055	test-auc:0.976538
# [241]	train-auc:0.997076	test-auc:0.976569
# [242]	train-auc:0.997094	test-auc:0.976568
# [243]	train-auc:0.997109	test-auc:0.976577
# [244]	train-auc:0.997131	test-auc:0.976614
# [245]	train-auc:0.997141	test-auc:0.976584
# [246]	train-auc:0.99716	test-auc:0.976561
# [247]	train-auc:0.997194	test-auc:0.976627
# [248]	train-auc:0.997227	test-auc:0.97661
# [249]	train-auc:0.997242	test-auc:0.976642
# [250]	train-auc:0.997255	test-auc:0.976694
# [251]	train-auc:0.997291	test-auc:0.976725
# [252]	train-auc:0.997306	test-auc:0.976715
# [253]	train-auc:0.997322	test-auc:0.976736
# [254]	train-auc:0.997334	test-auc:0.976781
# [255]	train-auc:0.997347	test-auc:0.976783
# [256]	train-auc:0.997368	test-auc:0.976785
# [257]	train-auc:0.99738	test-auc:0.976757
# [258]	train-auc:0.997386	test-auc:0.976707
# [259]	train-auc:0.997396	test-auc:0.976766
# [260]	train-auc:0.997407	test-auc:0.976778
# [261]	train-auc:0.99742	test-auc:0.976804
# [262]	train-auc:0.997435	test-auc:0.976773
# [263]	train-auc:0.997447	test-auc:0.976773
# [264]	train-auc:0.99746	test-auc:0.97683
# [265]	train-auc:0.997473	test-auc:0.976775
# [266]	train-auc:0.997477	test-auc:0.976788
# [267]	train-auc:0.997507	test-auc:0.976768
# [268]	train-auc:0.997536	test-auc:0.976759
# [269]	train-auc:0.997548	test-auc:0.976736
# [270]	train-auc:0.99756	test-auc:0.976763
# [271]	train-auc:0.997588	test-auc:0.976811
# [272]	train-auc:0.997597	test-auc:0.976801
# [273]	train-auc:0.997617	test-auc:0.976806
# [274]	train-auc:0.997642	test-auc:0.976783
# [275]	train-auc:0.997661	test-auc:0.976745
# [276]	train-auc:0.997678	test-auc:0.976784
# [277]	train-auc:0.997686	test-auc:0.976786
# [278]	train-auc:0.997701	test-auc:0.97679
# [279]	train-auc:0.997721	test-auc:0.9768
# [280]	train-auc:0.997759	test-auc:0.976801
# [281]	train-auc:0.997772	test-auc:0.97681
# [282]	train-auc:0.997786	test-auc:0.976834
# [283]	train-auc:0.997801	test-auc:0.976801
# [284]	train-auc:0.997811	test-auc:0.976799
# [285]	train-auc:0.99784	test-auc:0.976821
# [286]	train-auc:0.997865	test-auc:0.97683
# [287]	train-auc:0.997881	test-auc:0.97687
# [288]	train-auc:0.997904	test-auc:0.976881
# [289]	train-auc:0.997913	test-auc:0.976956
# [290]	train-auc:0.997931	test-auc:0.976991
# [291]	train-auc:0.997944	test-auc:0.976999
# [292]	train-auc:0.997954	test-auc:0.97705
# [293]	train-auc:0.997981	test-auc:0.977087
# [294]	train-auc:0.997999	test-auc:0.977125
# [295]	train-auc:0.998012	test-auc:0.977163
# [296]	train-auc:0.998036	test-auc:0.977127
# [297]	train-auc:0.998046	test-auc:0.977125
# [298]	train-auc:0.998064	test-auc:0.977139
# [299]	train-auc:0.998081	test-auc:0.977156
# [300]	train-auc:0.998085	test-auc:0.977207
# [301]	train-auc:0.998104	test-auc:0.977229
# [302]	train-auc:0.998133	test-auc:0.977235
# [303]	train-auc:0.998143	test-auc:0.977262
# [304]	train-auc:0.998153	test-auc:0.977267
# [305]	train-auc:0.998162	test-auc:0.977245
# [306]	train-auc:0.998172	test-auc:0.977273
# [307]	train-auc:0.998177	test-auc:0.977268
# [308]	train-auc:0.998188	test-auc:0.977237
# [309]	train-auc:0.998193	test-auc:0.977262
# [310]	train-auc:0.998204	test-auc:0.977256
# [311]	train-auc:0.998216	test-auc:0.977271
# [312]	train-auc:0.998228	test-auc:0.977271
# [313]	train-auc:0.998243	test-auc:0.977273
# [314]	train-auc:0.998251	test-auc:0.977266
# [315]	train-auc:0.998261	test-auc:0.977292
# [316]	train-auc:0.998277	test-auc:0.977308
# [317]	train-auc:0.998283	test-auc:0.977322
# [318]	train-auc:0.998304	test-auc:0.977327
# [319]	train-auc:0.998315	test-auc:0.977312
# [320]	train-auc:0.998325	test-auc:0.977326
# [321]	train-auc:0.998331	test-auc:0.977349
# [322]	train-auc:0.998338	test-auc:0.977354
# [323]	train-auc:0.998349	test-auc:0.977417
# [324]	train-auc:0.998365	test-auc:0.97745
# [325]	train-auc:0.998383	test-auc:0.977462
# [326]	train-auc:0.998394	test-auc:0.977471
# [327]	train-auc:0.998407	test-auc:0.9775
# [328]	train-auc:0.998418	test-auc:0.977483
# [329]	train-auc:0.998426	test-auc:0.977479
# [330]	train-auc:0.998435	test-auc:0.977485
# [331]	train-auc:0.998444	test-auc:0.977518
# [332]	train-auc:0.998452	test-auc:0.977552
# [333]	train-auc:0.998458	test-auc:0.977568
# [334]	train-auc:0.998466	test-auc:0.977607
# [335]	train-auc:0.998483	test-auc:0.977594
# [336]	train-auc:0.998495	test-auc:0.977554
# [337]	train-auc:0.998508	test-auc:0.977585
# [338]	train-auc:0.998527	test-auc:0.977582
# [339]	train-auc:0.998543	test-auc:0.977517
# [340]	train-auc:0.998553	test-auc:0.97756
# [341]	train-auc:0.998559	test-auc:0.977582
# [342]	train-auc:0.998572	test-auc:0.977572
# [343]	train-auc:0.99858	test-auc:0.977609
# [344]	train-auc:0.998589	test-auc:0.97768
# [345]	train-auc:0.998596	test-auc:0.9777
# [346]	train-auc:0.998606	test-auc:0.977697
# [347]	train-auc:0.998613	test-auc:0.977666
# [348]	train-auc:0.998621	test-auc:0.977726
# [349]	train-auc:0.998627	test-auc:0.977746
# [350]	train-auc:0.998629	test-auc:0.97775
# [351]	train-auc:0.998639	test-auc:0.977758
# [352]	train-auc:0.998653	test-auc:0.977773
# [353]	train-auc:0.998661	test-auc:0.977796
# [354]	train-auc:0.998669	test-auc:0.977826
# [355]	train-auc:0.998674	test-auc:0.977809
# [356]	train-auc:0.998685	test-auc:0.977852
# [357]	train-auc:0.998692	test-auc:0.977831
# [358]	train-auc:0.998698	test-auc:0.9778
# [359]	train-auc:0.998705	test-auc:0.97781
# [360]	train-auc:0.998711	test-auc:0.977841
# [361]	train-auc:0.998718	test-auc:0.977831
# [362]	train-auc:0.998737	test-auc:0.977842
# [363]	train-auc:0.998743	test-auc:0.977804
# [364]	train-auc:0.998753	test-auc:0.977826
# [365]	train-auc:0.998761	test-auc:0.977779
# [366]	train-auc:0.998769	test-auc:0.977736
# [367]	train-auc:0.998774	test-auc:0.977756
# [368]	train-auc:0.998781	test-auc:0.977768
# [369]	train-auc:0.998787	test-auc:0.977757
# [370]	train-auc:0.998793	test-auc:0.977793
# [371]	train-auc:0.998804	test-auc:0.97779
# [372]	train-auc:0.99881	test-auc:0.977781
# [373]	train-auc:0.998816	test-auc:0.977813
# [374]	train-auc:0.99882	test-auc:0.977778
# [375]	train-auc:0.998831	test-auc:0.977763
# [376]	train-auc:0.998836	test-auc:0.977755
# Stopping. Best iteration:
# [356]	train-auc:0.998685	test-auc:0.977852
#
# fit identity_hate
# [0]	train-auc:0.840197	test-auc:0.804017
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 20 rounds.
# [1]	train-auc:0.851011	test-auc:0.808495
# [2]	train-auc:0.852343	test-auc:0.80814
# [3]	train-auc:0.858037	test-auc:0.81025
# [4]	train-auc:0.859572	test-auc:0.810366
# [5]	train-auc:0.873477	test-auc:0.836836
# [6]	train-auc:0.878249	test-auc:0.835718
# [7]	train-auc:0.878518	test-auc:0.835929
# [8]	train-auc:0.879215	test-auc:0.836323
# [9]	train-auc:0.884593	test-auc:0.836324
# [10]	train-auc:0.888394	test-auc:0.839622
# [11]	train-auc:0.898916	test-auc:0.854557
# [12]	train-auc:0.90147	test-auc:0.853596
# [13]	train-auc:0.902315	test-auc:0.853321
# [14]	train-auc:0.902357	test-auc:0.853331
# [15]	train-auc:0.907919	test-auc:0.856603
# [16]	train-auc:0.909247	test-auc:0.85973
# [17]	train-auc:0.912338	test-auc:0.861488
# [18]	train-auc:0.91303	test-auc:0.861455
# [19]	train-auc:0.913302	test-auc:0.861573
# [20]	train-auc:0.914754	test-auc:0.860743
# [21]	train-auc:0.914976	test-auc:0.860801
# [22]	train-auc:0.915046	test-auc:0.860844
# [23]	train-auc:0.914974	test-auc:0.860267
# [24]	train-auc:0.915073	test-auc:0.860337
# [25]	train-auc:0.915083	test-auc:0.860157
# [26]	train-auc:0.915345	test-auc:0.860352
# [27]	train-auc:0.919162	test-auc:0.864154
# [28]	train-auc:0.919237	test-auc:0.863981
# [29]	train-auc:0.919792	test-auc:0.865743
# [30]	train-auc:0.929465	test-auc:0.871718
# [31]	train-auc:0.92981	test-auc:0.871507
# [32]	train-auc:0.929973	test-auc:0.873406
# [33]	train-auc:0.930223	test-auc:0.875498
# [34]	train-auc:0.936965	test-auc:0.879277
# [35]	train-auc:0.939667	test-auc:0.883758
# [36]	train-auc:0.942284	test-auc:0.891992
# [37]	train-auc:0.959615	test-auc:0.913763
# [38]	train-auc:0.961816	test-auc:0.919215
# [39]	train-auc:0.962065	test-auc:0.9185
# [40]	train-auc:0.965918	test-auc:0.928744
# [41]	train-auc:0.965872	test-auc:0.928796
# [42]	train-auc:0.967163	test-auc:0.928671
# [43]	train-auc:0.9671	test-auc:0.928742
# [44]	train-auc:0.971036	test-auc:0.933417
# [45]	train-auc:0.974118	test-auc:0.933569
# [46]	train-auc:0.976423	test-auc:0.935442
# [47]	train-auc:0.977541	test-auc:0.938084
# [48]	train-auc:0.979065	test-auc:0.939774
# [49]	train-auc:0.98019	test-auc:0.938397
# [50]	train-auc:0.982332	test-auc:0.939913
# [51]	train-auc:0.982554	test-auc:0.939825
# [52]	train-auc:0.983735	test-auc:0.942622
# [53]	train-auc:0.984032	test-auc:0.944126
# [54]	train-auc:0.985022	test-auc:0.94788
# [55]	train-auc:0.986111	test-auc:0.948145
# [56]	train-auc:0.986931	test-auc:0.94816
# [57]	train-auc:0.987387	test-auc:0.948216
# [58]	train-auc:0.988114	test-auc:0.950164
# [59]	train-auc:0.98944	test-auc:0.952754
# [60]	train-auc:0.989784	test-auc:0.953819
# [61]	train-auc:0.990154	test-auc:0.954504
# [62]	train-auc:0.990454	test-auc:0.955575
# [63]	train-auc:0.991439	test-auc:0.955469
# [64]	train-auc:0.991763	test-auc:0.95663
# [65]	train-auc:0.992038	test-auc:0.957361
# [66]	train-auc:0.99227	test-auc:0.957622
# [67]	train-auc:0.992901	test-auc:0.957578
# [68]	train-auc:0.993132	test-auc:0.957274
# [69]	train-auc:0.993237	test-auc:0.95782
# [70]	train-auc:0.993453	test-auc:0.958032
# [71]	train-auc:0.993874	test-auc:0.958537
# [72]	train-auc:0.993932	test-auc:0.958672
# [73]	train-auc:0.994351	test-auc:0.95913
# [74]	train-auc:0.994528	test-auc:0.959974
# [75]	train-auc:0.994795	test-auc:0.959723
# [76]	train-auc:0.995081	test-auc:0.960733
# [77]	train-auc:0.99524	test-auc:0.960654
# [78]	train-auc:0.995429	test-auc:0.960635
# [79]	train-auc:0.99563	test-auc:0.961301
# [80]	train-auc:0.995823	test-auc:0.962463
# [81]	train-auc:0.995897	test-auc:0.963445
# [82]	train-auc:0.995963	test-auc:0.96347
# [83]	train-auc:0.996256	test-auc:0.963652
# [84]	train-auc:0.996528	test-auc:0.964309
# [85]	train-auc:0.996739	test-auc:0.964491
# [86]	train-auc:0.99687	test-auc:0.964507
# [87]	train-auc:0.997002	test-auc:0.96447
# [88]	train-auc:0.997134	test-auc:0.964588
# [89]	train-auc:0.99718	test-auc:0.964667
# [90]	train-auc:0.997301	test-auc:0.964415
# [91]	train-auc:0.997434	test-auc:0.964365
# [92]	train-auc:0.997482	test-auc:0.965006
# [93]	train-auc:0.997518	test-auc:0.965495
# [94]	train-auc:0.997611	test-auc:0.965592
# [95]	train-auc:0.997681	test-auc:0.965569
# [96]	train-auc:0.997748	test-auc:0.9662
# [97]	train-auc:0.997809	test-auc:0.966442
# [98]	train-auc:0.997877	test-auc:0.966726
# [99]	train-auc:0.997936	test-auc:0.966807
# [100]	train-auc:0.998	test-auc:0.966889
# [101]	train-auc:0.998038	test-auc:0.966694
# [102]	train-auc:0.998091	test-auc:0.966655
# [103]	train-auc:0.99815	test-auc:0.966728
# [104]	train-auc:0.998178	test-auc:0.966524
# [105]	train-auc:0.998263	test-auc:0.966258
# [106]	train-auc:0.998299	test-auc:0.966929
# [107]	train-auc:0.998351	test-auc:0.967502
# [108]	train-auc:0.998431	test-auc:0.967778
# [109]	train-auc:0.99846	test-auc:0.96808
# [110]	train-auc:0.998501	test-auc:0.968246
# [111]	train-auc:0.998547	test-auc:0.96848
# [112]	train-auc:0.998602	test-auc:0.968685
# [113]	train-auc:0.99863	test-auc:0.968831
# [114]	train-auc:0.998679	test-auc:0.968889
# [115]	train-auc:0.998734	test-auc:0.968656
# [116]	train-auc:0.998787	test-auc:0.968632
# [117]	train-auc:0.998814	test-auc:0.968606
# [118]	train-auc:0.998846	test-auc:0.968804
# [119]	train-auc:0.998866	test-auc:0.96909
# [120]	train-auc:0.998911	test-auc:0.969085
# [121]	train-auc:0.998943	test-auc:0.968986
# [122]	train-auc:0.998983	test-auc:0.969182
# [123]	train-auc:0.998996	test-auc:0.968949
# [124]	train-auc:0.999015	test-auc:0.968739
# [125]	train-auc:0.999055	test-auc:0.968841
# [126]	train-auc:0.999086	test-auc:0.968952
# [127]	train-auc:0.999113	test-auc:0.969108
# [128]	train-auc:0.999142	test-auc:0.969027
# [129]	train-auc:0.999168	test-auc:0.96928
# [130]	train-auc:0.999189	test-auc:0.969399
# [131]	train-auc:0.999212	test-auc:0.969566
# [132]	train-auc:0.999223	test-auc:0.969953
# [133]	train-auc:0.999232	test-auc:0.970122
# [134]	train-auc:0.999258	test-auc:0.969987
# [135]	train-auc:0.999284	test-auc:0.969761
# [136]	train-auc:0.999299	test-auc:0.969784
# [137]	train-auc:0.999318	test-auc:0.969839
# [138]	train-auc:0.999327	test-auc:0.969982
# [139]	train-auc:0.999338	test-auc:0.970262
# [140]	train-auc:0.99936	test-auc:0.970202
# [141]	train-auc:0.999371	test-auc:0.970178
# [142]	train-auc:0.999384	test-auc:0.970075
# [143]	train-auc:0.999393	test-auc:0.969967
# [144]	train-auc:0.99941	test-auc:0.970022
# [145]	train-auc:0.999418	test-auc:0.970258
# [146]	train-auc:0.999437	test-auc:0.969994
# [147]	train-auc:0.999453	test-auc:0.969921
# [148]	train-auc:0.999466	test-auc:0.9698
# [149]	train-auc:0.999474	test-auc:0.969564
# [150]	train-auc:0.999483	test-auc:0.969657
# [151]	train-auc:0.999488	test-auc:0.969921
# [152]	train-auc:0.999498	test-auc:0.96986
# [153]	train-auc:0.999509	test-auc:0.969757
# [154]	train-auc:0.99953	test-auc:0.969796
# [155]	train-auc:0.999534	test-auc:0.969997
# [156]	train-auc:0.999538	test-auc:0.970153
# [157]	train-auc:0.999557	test-auc:0.970063
# [158]	train-auc:0.999571	test-auc:0.970002
# [159]	train-auc:0.99958	test-auc:0.970087
# Stopping. Best iteration:
# [139]	train-auc:0.999338	test-auc:0.970262

# %%
gc.collect()
# Out:
# 223

# %%
subm = pd.read_csv('sample_submission.csv')    
submid = pd.DataFrame({'id': subm["id"]})
submission = pd.concat([submid, pd.DataFrame(preds, columns = col)], axis=1)
submission.to_csv('xgb.csv', index=False)

# %%
1
